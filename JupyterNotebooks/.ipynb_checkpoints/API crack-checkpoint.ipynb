# %%
import os
from dotenv import load_dotenv
load_dotenv()
import pandas as pd
import re 
import numpy as np
from IPython.display import Image
from IPython.core.display import HTML
import requests

# %%
df = pd.read_csv('../books.csv', error_bad_lines=False)
# Out:
# b'Skipping line 4012: expected 10 fields, saw 11\nSkipping line 5688: expected 10 fields, saw 11\nSkipping line 7056: expected 10 fields, saw 11\nSkipping line 10601: expected 10 fields, saw 11\nSkipping line 10668: expected 10 fields, saw 11\n'

# %%
df
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           3  Harry Potter and the Sorcerer's Stone (Harry P...
# 3           4  Harry Potter and the Chamber of Secrets (Harry...
# 4           5  Harry Potter and the Prisoner of Azkaban (Harr...
# ...       ...                                                ...
# 13709   47699                                     M Is for Magic
# 13710   47700                                       Black Orchid
# 13711   47701                        InterWorld (InterWorld  #1)
# 13712   47708                                The Faeries' Oracle
# 13713   47709                      The World of The Dark Crystal
#
#                              authors  average_rating        isbn  \
# 0         J.K. Rowling-Mary GrandPré            4.56  0439785960
# ...

# %%
df = df[df.average_rating > 4]

# %%
df["genre"] = np.nan
# Out:
# /home/clara/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def dropcol(dframe):
    return dframe.drop(['ratings_count', 'text_reviews_count','bookID'], axis=1)
dropcol(df)
# Out:
#                                                    title  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...
# 1      Harry Potter and the Order of the Phoenix (Har...
# 2      Harry Potter and the Sorcerer's Stone (Harry P...
# 3      Harry Potter and the Chamber of Secrets (Harry...
# 4      Harry Potter and the Prisoner of Azkaban (Harr...
# ...                                                  ...
# 13705                                      American Gods
# 13706          The Day I Swapped My Dad for Two Goldfish
# 13708                        The Sandman: King of Dreams
# 13712                                The Faeries' Oracle
# 13713                      The World of The Dark Crystal
#
#                            authors  average_rating        isbn         isbn13  \
# 0       J.K. Rowling-Mary GrandPré            4.56  0439785960  9780439785969
# 1       J.K. Rowling-Mary GrandPré            4.49  0439358078  9780439358071
# ...

# %%
def goodReadRequest(ISBN):
    url = 'https://openlibrary.org/api/books?bibkeys=ISBN:{}&jscmd=data&format=json'.format(ISBN)
    res = requests.get(url)
    return res

# %%
grData=[]
for i in df["genre"]:
    if i==None:
        for j in df["isbn13"]:
            grData.append(goodReadRequest("{}".format(j)).json())

# %%
print(len(grData))
# Out:
# 0

# %%
grDat= list(filter(None,grData))

# %%
print(len(grDat))

# %%
grDat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-83be1cff0b2e> in <module>
# ----> 1 grDat
#
# NameError: name 'grDat' is not defined

# %%
gr=grDat[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-23c13fef5581> in <module>
# ----> 1 gr=grDat[:10]
#
# NameError: name 'grDat' is not defined

# %%
publishers=[]
for g in gr:
    for e in g.values():
        if 'publishers' in e.values():
            print(True)
        else:
            print(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-871234696a08> in <module>
#       1 publishers=[]
# ----> 2 for g in gr:
#       3     for e in g.values():
#       4         if 'publishers' in e.values():
#       5             print(True)
#
# NameError: name 'gr' is not defined

# %%
print(len(publishers))
# Out:
# 102

# %%
test_dict = {}
filtrarDF=[]
for deita in grData:
        if deita == test_dict:
            filtrarDF.append("False")
        else:
            for key in deita:
                filtrarDF.append(key)

# %%
print(len(filtrarDF))
# Out:
# 5758

# %%
df1=pd.DataFrame(list(filtrarDF), columns=["filtro"])

# %%
df1
# Out:
#                   filtro
# 0     ISBN:9780439785969
# 1     ISBN:9780439358071
# 2     ISBN:9780439554930
# 3                  False
# 4     ISBN:9780439655484
# ...                  ...
# 5753  ISBN:9781594970993
# 5754  ISBN:9780060587017
# 5755  ISBN:9780811835923
# 5756  ISBN:9780743201117
# 5757               False
#
# [5758 rows x 1 columns]

# %%
df["filtro"]=filtrarDF
# Out:
# /home/clara/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
display(df)
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           3  Harry Potter and the Sorcerer's Stone (Harry P...
# 3           4  Harry Potter and the Chamber of Secrets (Harry...
# 4           5  Harry Potter and the Prisoner of Azkaban (Harr...
# ...       ...                                                ...
# 13705   47692                                      American Gods
# 13706   47693          The Day I Swapped My Dad for Two Goldfish
# 13708   47697                        The Sandman: King of Dreams
# 13712   47708                                The Faeries' Oracle
# 13713   47709                      The World of The Dark Crystal
#
#                            authors  average_rating        isbn         isbn13  \
# 0       J.K. Rowling-Mary GrandPré            4.56  0439785960  9780439785969
# ...

# %%
filtered = df[(df['filtro']!="False")]

print(filtered.shape)
filtered.head()
# Out:
# (5532, 11)
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       3  Harry Potter and the Sorcerer's Stone (Harry P...
# 4       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 5       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling-Mary GrandPré            4.56  0439785960  9780439785969
# 1  J.K. Rowling-Mary GrandPré            4.49  0439358078  9780439358071
# 2  J.K. Rowling-Mary GrandPré            4.47  0439554934  9780439554930
# 4  J.K. Rowling-Mary GrandPré            4.55  043965548X  9780439655484
# 5  J.K. Rowling-Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code  # num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        1944099               26249
# ...

# %%
'''
ncolumn=[]
subject=[]
for deita in grDat:
    for dic in deita.values():
        if 'subjects' in dic.keys():
            for sub in dic['subjects']:
                subject.append(sub["name"])
            ncolumn.append(subject)
        else:
            ncolumn.append(False)
'''

# %%
dicionario = {"subject":[1,2,3]}
