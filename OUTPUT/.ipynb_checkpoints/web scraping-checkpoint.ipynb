# %%
import os
from dotenv import load_dotenv
load_dotenv()
from bs4 import BeautifulSoup
import pandas as pd
import re 
import numpy as np
from IPython.display import Image
from IPython.core.display import HTML
import requests 

df = pd.read_csv('../books.csv', error_bad_lines=False)
# Out:
# b'Skipping line 4012: expected 10 fields, saw 11\nSkipping line 5688: expected 10 fields, saw 11\nSkipping line 7056: expected 10 fields, saw 11\nSkipping line 10601: expected 10 fields, saw 11\nSkipping line 10668: expected 10 fields, saw 11\n'

# %%
url = 'https://en.wikipedia.org/wiki/List_of_best-selling_books'

# %%
res= requests.get(url)
html=res.text
html[:10]
soup = BeautifulSoup(html, "html.parser")

# %%
table = soup.findAll('table')[0]
print(table)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Book</th>
# <th>Author(s)</th>
# <th>Original language</th>
# <th>First published</th>
# <th>Approximate sales</th>
# <th>Genre
# </th></tr>
# <tr>
# <td><i><a href="/wiki/The_Lord_of_the_Rings" title="The Lord of the Rings">The Lord of the Rings</a></i></td>
# <td><a href="/wiki/J._R._R._Tolkien" title="J. R. R. Tolkien">J. R. R. Tolkien</a></td>
# <td>English</td>
# <td>1954</td>
# <td>150 million<sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup><sup class="reference" id="cite_ref-Chalton_2017_129_9-1"><a href="#cite_note-Chalton_2017_129-9">[9]</a></sup><sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[16]</a></sup>
# </td>
# <td><a href="/wiki/Fantasy" title="Fantasy">fantasy</a>
# </td></tr>
# <tr>
# <td><i><a href="/wiki/The_Alchemist_(novel)" title="The Alchemist (novel)">The Alchemist</a></i> (<i>O Alquimista</i>)</td>
# ...

# %%
#<td><i><a href="/wiki/The_Lord_of_the_Rings" title="The Lord of the Rings">T
books=soup.findAll('td')
books
# Out:
# [<td><i><a href="/wiki/The_Lord_of_the_Rings" title="The Lord of the Rings">The Lord of the Rings</a></i></td>,
#  <td><a href="/wiki/J._R._R._Tolkien" title="J. R. R. Tolkien">J. R. R. Tolkien</a></td>,
#  <td>English</td>,
#  <td>1954</td>,
#  <td>150 million<sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup><sup class="reference" id="cite_ref-Chalton_2017_129_9-1"><a href="#cite_note-Chalton_2017_129-9">[9]</a></sup><sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[16]</a></sup>
#  </td>,
#  <td><a href="/wiki/Fantasy" title="Fantasy">fantasy</a>
#  </td>,
#  <td><i><a href="/wiki/The_Alchemist_(novel)" title="The Alchemist (novel)">The Alchemist</a></i> (<i>O Alquimista</i>)</td>,
#  <td><a href="/wiki/Paulo_Coelho" title="Paulo Coelho">Paulo Coelho</a></td>,
#  <td>Portuguese</td>,
#  <td>1988</td>,
# ...

# %%
titles=[]
for book in books:
    titles.append(book.get('title'))
    
print(titles)
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, N
# ...

# %%
'''
filas= table.find_all('tr')[:1]
top=[]
for fila in filas:
    celdas =fila.find_all('td')
    books={
        "title":celdas[1].find('a').text.strip(),
        "author":celdas[2].text,
        "original_language":celdas[3].text,
        "genre":celdas[6].text
    }
    top.append(books)
    
print(celdas)
'''
